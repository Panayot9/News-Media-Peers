# %%
import pandas as pd
import sys
sys.path.insert(0, '../../../')

from notebooks.utils import (
    get_referral_sites_edges, export_model_as_feature, create_node2vec_model
)
from train import run_experiment

# %% [markdown]
# # Load audience overlap edges for level 1

# %%
level = 1
referral_sites_NODES = get_referral_sites_edges(data_year=2020, level=level)

print(referral_sites_NODES[:5])
# Out:
# 02-26 23:33:46 notebooks.utils INFO     Processing level 0
# 02-26 23:33:46 notebooks.utils INFO     Node length: 3258
# 02-26 23:33:46 notebooks.utils INFO     Distinct node length: 3258
# 02-26 23:33:46 notebooks.utils INFO     Processing level 1
# 02-26 23:33:47 notebooks.utils INFO     Node length: 9178
# 02-26 23:33:47 notebooks.utils INFO     Distinct node length: 9178
# [('digitaljournal.com', 'transparencymarketresearch.com'), ('gallup.com', 'strengthsquest.com'), ('other98.com', 'cancelkavanaugh.com'), ('crimethinc.com', 'sproutdistro.com'), ('puppetstringnews.com', 'bigleaguepolitics.com')]

# %%
edge_df = pd.DataFrame(referral_sites_NODES, columns=['source', 'target'])

edge_df.head()
# Out:
#                  source                          target
# 0    digitaljournal.com  transparencymarketresearch.com
# 1            gallup.com              strengthsquest.com
# 2           other98.com             cancelkavanaugh.com
# 3        crimethinc.com                sproutdistro.com
# 4  puppetstringnews.com           bigleaguepolitics.com

# %% [markdown]
# # Create Graph

# %%
import stellargraph as sg

G = sg.StellarGraph(edges=edge_df)

print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 6927, Edges: 12436
#
#  Node types:
#   default: [6927]
#     Features: none
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [12436]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# # Create Node2Vec models

# %%
models = create_node2vec_model(G, dimensions=[64, 128, 256, 512, 1024], is_weighted=False,
                               prefix='corpus_2020_referral_sites_lvl_one')
# Out:
# Start creating random walks
# Number of random walks: 69270
# 02-26 23:43:27 gensim.models.word2vec INFO     collecting all words and their counts
# 02-26 23:43:27 gensim.models.word2vec INFO     PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 02-26 23:43:27 gensim.models.word2vec INFO     PROGRESS: at sentence #10000, processed 1000000 words, keeping 6926 word types
# 02-26 23:43:28 gensim.models.word2vec INFO     PROGRESS: at sentence #20000, processed 2000000 words, keeping 6927 word types
# 64 corpus_2020_referral_sites_lvl_one_unweighted_64D.model
# 02-26 23:43:28 gensim.models.word2vec INFO     PROGRESS: at sentence #30000, processed 3000000 words, keeping 6927 word types
# 02-26 23:43:28 gensim.models.word2vec INFO     PROGRESS: at sentence #40000, processed 4000000 words, keeping 6927 word types
# 02-26 23:43:28 gensim.models.word2vec INFO     PROGRESS: at sentence #50000, processed 5000000 words, keeping 6927 word types
# 02-26 23:43:28 gensim.models.word2vec INFO     PROGRESS: at sentence #60000, processed 6000000 words, keeping 6927 word types
# 02-26 23:43:28 gensim.models.word2vec INFO     collected 6927 word types from a corpus of 6927000 raw words and 69270 sentences
# 02-26 23:43:28 gensim.models.word2vec INFO     Creating a fresh vocabulary
# 02-26 23:43:28 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 6927 unique words (100.0%% of original 6927, drops 0)', 'datetime': '2022-02-26T23:43:28.485086', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:43:28 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 6927000 word corpus (100.0%% of original 6927000, drops 0)', 'datetime': '2022-02-26T23:43:28.485805', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:43:28 gensim.models.word2vec INFO     deleting the raw counts dictionary of 6927 items
# 02-26 23:43:28 gensim.models.word2vec INFO     sample=0.001 downsamples 0 most-common words
# 02-26 23:43:28 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 6927000 word corpus (100.0%% of prior 6927000)', 'datetime': '2022-02-26T23:43:28.531994', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:43:28 gensim.models.word2vec INFO     estimated required memory for 6927 words and 64 dimensions: 7010124 bytes
# 02-26 23:43:28 gensim.models.word2vec INFO     resetting layer weights
# 02-26 23:43:28 gensim.utils INFO     Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-02-26T23:43:28.603462', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 02-26 23:43:28 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training model with 2 workers on 6927 vocabulary and 64 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-02-26T23:43:28.604158', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 02-26 23:43:29 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 6.64% examples, 459834 words/s, in_qsize 3, out_qsize 0
# 02-26 23:43:30 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 13.71% examples, 468232 words/s, in_qsize 3, out_qsize 0
# 02-26 23:43:31 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at
gensim.utils INFO     saved /Users/panayot/Documents/News-Media-Peers/models/corpus_2020_referral_sites_lvl_one_unweighted_64D.model
# 02-26 23:44:30 gensim.models.word2vec INFO     collecting all words and their counts
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #10000, processed 1000000 words, keeping 6926 word types
# Successful save of model: corpus_2020_referral_sites_lvl_one_unweighted_64D.model!
# 128 corpus_2020_referral_sites_lvl_one_unweighted_128D.model
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #20000, processed 2000000 words, keeping 6927 word types
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #30000, processed 3000000 words, keeping 6927 word types
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #40000, processed 4000000 words, keeping 6927 word types
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #50000, processed 5000000 words, keeping 6927 word types
# 02-26 23:44:30 gensim.models.word2vec INFO     PROGRESS: at sentence #60000, processed 6000000 words, keeping 6927 word types
# 02-26 23:44:30 gensim.models.word2vec INFO     collected 6927 word types from a corpus of 6927000 raw words and 69270 sentences
# 02-26 23:44:30 gensim.models.word2vec INFO     Creating a fresh vocabulary
# 02-26 23:44:30 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 6927 unique words (100.0%% of original 6927, drops 0)', 'datetime': '2022-02-26T23:44:30.992880', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:44:30 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 6927000 word corpus (100.0%% of original 6927000, drops 0)', 'datetime': '2022-02-26T23:44:30.993842', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:44:31 gensim.models.word2vec INFO     deleting the raw counts dictionary of 6927 items
# 02-26 23:44:31 gensim.models.word2vec INFO     sample=0.001 downsamples 0 most-common words
# 02-26 23:44:31 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 6927000 word corpus (100.0%% of prior 6927000)', 'datetime': '2022-02-26T23:44:31.042274', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:44:31 gensim.models.word2vec INFO     estimated required memory for 6927 words and 128 dimensions: 10556748 bytes
# 02-26 23:44:31 gensim.models.word2vec INFO     resetting layer weights
# 02-26 23:44:31 gensim.utils INFO     Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-02-26T23:44:31.121345', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 02-26 23:44:31 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training model with 2 workers on 6927 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-02-26T23:44:31.122069', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 02-26 23:44:32 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 3.90% examples, 255044 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:33 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 9.38% examples, 307939 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:34 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 15.59% examples, 347166 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:35 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 21.22% examples, 353481 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:36 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 27.28% examples, 364636 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:37 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 33.06% examples, 369735 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:38 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 39.41% examples, 378468 words/s, in_qsize 4, out_qsize 0
# 02-26 23:44:39 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 46.05% examples, 387836 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:40 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 53.27% examples, 399174 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:41 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 59.91% examples, 403506 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:42 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 66.26% examples, 405452 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:43 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 74.35% examples, 417636 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:44 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 81.28% examples, 421855 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:45 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 87.63% examples, 422895 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:46 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 94.85% examples, 427637 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:47 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 02-26 23:44:47 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 02-26 23:44:47 gensim.models.word2vec INFO     EPOCH - 1 : training on 6927000 raw words (6927000 effective words) took 16.2s, 428547 effective words/s
# 02-26 23:44:48 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 7.36% examples, 490737 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:49 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 15.45% examples, 518470 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:50 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 21.65% examples, 489509 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:51 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 28.15% examples, 476768 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:52 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 34.79% examples, 471992 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:53 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 39.70% examples, 449562 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:54 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 45.76% examples, 445307 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:55 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 51.83% examples, 441412 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:56 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 59.04% examples, 447647 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:57 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 65.97% examples, 449964 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:58 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 73.77% examples, 457848 words/s, in_qsize 3, out_qsize 0
# 02-26 23:44:59 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 82.14% examples, 467812 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:00 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 88.78% examples, 466398 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:01 gensim.models.word2vec INFO     EPOCH 2 - PROGRESS: at 95.42% examples, 465291 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:02 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 02-26 23:45:02 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 02-26 23:45:02 gensim.models.word2vec INFO     EPOCH - 2 : training on 6927000 raw words (6927000 effective words) took 14.9s, 464879 effective words/s
# 02-26 23:45:03 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 8.23% examples, 558989 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:04 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 17.03% examples, 583868 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:05 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 25.26% examples, 576569 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:06 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 33.49% examples, 574582 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:07 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 41.43% examples, 568383 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:08 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 50.38% examples, 573895 words/s, in_qsize 4, out_qsize 1
# 02-26 23:45:09 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 58.76% examples, 573446 words/s, in_qsize 2, out_qsize 1
# 02-26 23:45:10 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 67.42% examples, 576428 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:11 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 76.08% examples, 577658 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:12 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 84.74% examples, 579727 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:13 gensim.models.word2vec INFO     EPOCH 3 - PROGRESS: at 93.40% examples, 580368 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:14 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 02-26 23:45:14 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 02-26 23:45:14 gensim.models.word2vec INFO     EPOCH - 3 : training on 6927000 raw words (6927000 effective words) took 11.9s, 581131 effective words/s
# 02-26 23:45:15 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 8.23% examples, 558471 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:16 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 16.60% examples, 566854 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:17 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 25.26% examples, 572683 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:18 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 33.93% examples, 579112 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:19 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 42.59% examples, 580746 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:20 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 51.25% examples, 583282 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:21 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 59.91% examples, 583501 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:22 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 68.72% examples, 586706 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:23 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 77.23% examples, 585725 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:24 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 85.90% examples, 586968 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:25 gensim.models.word2vec INFO     EPOCH 4 - PROGRESS: at 93.98% examples, 582629 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:26 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 02-26 23:45:26 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 02-26 23:45:26 gensim.models.word2vec INFO     EPOCH - 4 : training on 6927000 raw words (6927000 effective words) took 12.1s, 572675 effective words/s
# 02-26 23:45:27 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 7.94% examples, 536152 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:28 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 15.45% examples, 520212 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:29 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 23.24% examples, 525086 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:30 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 31.18% examples, 530773 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:31 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 39.12% examples, 532392 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:32 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 46.92% examples, 533445 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:33 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 54.14% examples, 527207 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:34 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 61.50% examples, 524817 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:35 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 68.28% examples, 517328 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:36 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 75.50% examples, 515179 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:37 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 82.29% examples, 510810 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:38 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 89.65% examples, 510005 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:39 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 98.02% examples, 514621 words/s, in_qsize 3, out_qsize 0
# 02-26 23:45:39 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 02-26 23:45:39 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 02-26 23:45:39 gensim.models.word2vec INFO     EPOCH - 5 : training on 6927000 raw words (6927000 effective words) took 13.5s, 514699 effective words/s
# 02-26 23:45:39 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training on 34635000 raw words (34635000 effective words) took 68.6s, 505221 effective words/s', 'datetime': '2022-02-26T23:45:39.677672', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 02-26 23:45:39 gensim.utils INFO     Word2Vec lifecycle event {'params': 'Word2Vec(vocab=6927, vector_size=128, alpha=0.025)', 'datetime': '2022-02-26T23:45:39.678186', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 02-26 23:45:39 gensim.utils INFO     Word2Vec lifecycle event {'fname_or_handle': '/Users/panayot/Documents/News-Media-Peers/models/corpus_2020_referral_sites_lvl_one_unweighted_128D.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-02-26T23:45:39.679401', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# 02-26 23:45:39 gensim.utils INFO     not storing attribute cum_table
# 02-26 23:45:39 gensim.utils INFO     saved /Users/panayot/Documents/News-Media-Peers/models/corpus_2020_referral_sites_lvl_one_unweighted_128D.model
# 02-26 23:45:39 gensim.models.word2vec INFO     collecting all words and their counts
# 02-26 23:45:39 gensim.models.word2vec INFO     PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 02-26 23:45:39 gensim.models.word2vec INFO     PROGRESS: at sentence #10000, processed 1000000 words, keeping 6926 word types
# Successful save of model: corpus_2020_referral_sites_lvl_one_unweighted_128D.model!
# 256 corpus_2020_referral_sites_lvl_one_unweighted_256D.model
# 02-26 23:45:39 gensim.models.word2vec INFO     PROGRESS: at sentence #20000, processed 2000000 words, keeping 6927 word types
# 02-26 23:45:40 gensim.models.word2vec INFO     PROGRESS: at sentence #30000, processed 3000000 words, keeping 6927 word types
# 02-26 23:45:40 gensim.models.word2vec INFO     PROGRESS: at sentence #40000, processed 4000000 words, keeping 6927 word types
# 02-26 23:45:40 gensim.models.word2vec INFO     PROGRESS: at sentence #50000, processed 5000000 words, keeping 6927 word types
# 02-26 23:45:40 gensim.models.word2vec INFO     PROGRESS: at sentence #60000, processed 6000000 words, keeping 6927 word types
# 02-26 23:45:40 gensim.models.word2vec INFO     collected 6927 word types from a corpus of 6927000 raw words and 69270 sentences
# 02-26 23:45:40 gensim.models.word2vec INFO     Creating a fresh vocabulary
# 02-26 23:45:40 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 6927 unique words (100.0%% of original 6927, drops 0)', 'datetime': '2022-02-26T23:45:40.456064', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:45:40 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 6927000 word corpus (100.0%% of original 6927000, drops 0)', 'datetime': '2022-02-26T23:45:40.456924', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:45:40 gensim.models.word2vec INFO     deleting the raw counts dictionary of 6927 items
# 02-26 23:45:40 gensim.models.word2vec INFO     sample=0.001 downsamples 0 most-common words
# 02-26 23:45:40 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 6927000 word corpus (100.0%% of prior 6927000)', 'datetime': '2022-02-26T23:45:40.512863', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 02-26 23:45:40 gensim.models.word2vec INFO     estimated required memory for 6927 words and 256 dimensions: 17649996 bytes
# 02-26 23:45:40 gensim.models.word2vec INFO     resetting layer weights
# 02-26 23:45:40 gensim.utils INFO     Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-02-26T23:45:40.604253', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 02-26 23:45:40 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training model with 2 workers on 6927 vocabulary and 256 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-02-26T23:45:40.604954', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 02-26 23:45:41 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at
 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 02-26 23:56:30 gensim.utils INFO     Word2Vec lifecycle event {'fname_or_handle': '/Users/panayot/Documents/News-Media-Peers/models/corpus_2020_referral_sites_lvl_one_unweighted_1024D.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-02-26T23:56:30.974154', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# 02-26 23:56:30 gensim.utils INFO     not storing attribute cum_table
# 02-26 23:56:31 gensim.utils INFO     saved /Users/panayot/Documents/News-Media-Peers/models/corpus_2020_referral_sites_lvl_one_unweighted_1024D.model
# Successful save of model: corpus_2020_referral_sites_lvl_one_unweighted_1024D.model!

# %% [markdown]
# # Export embeddings as feature

# %%
for model_name, model in models.items():
    print(f'Processing model: {model_name}')
    embeddings_wv = {site: model.wv.get_vector(site).tolist() for site in G.nodes()}
    export_model_as_feature(embeddings_wv, model_name, data_year='2020')
    run_experiment(features=model_name, dataset='acl2020', task='fact')
    print('\n', '-'*50, '\n')
    run_experiment(features=model_name, dataset='acl2020', task='bias')
    print('\n', '='*50, '\n')
# Out:
# Processing model: corpus_2020_referral_sites_lvl_one_unweighted_64D.model
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                        |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_64D.model |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+
# 02-26 23:56:32 train        INFO     Start training...
# 02-26 23:56:33 train        INFO     Fold: 0
# 02-26 23:56:39 train        INFO     Fold: 1
# 02-26 23:56:44 train        INFO     Fold: 2
# 02-26 23:56:47 train        INFO     Fold: 3
# 02-26 23:56:51 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                        |      Macro-F1     |      Accuracy     | Flip error-rate  |        MAE         |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_64D.model | 54.65453796654556 | 63.67869615832363 | 9.19674039580908 | 0.4551804423748545 |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
#
#  --------------------------------------------------
#
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                        |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_64D.model |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+
# 02-26 23:56:55 train        INFO     Start training...
# 02-26 23:56:55 train        INFO     Fold: 0
# 02-26 23:56:59 train        INFO     Fold: 1
# 02-26 23:57:04 train        INFO     Fold: 2
# 02-26 23:57:08 train        INFO     Fold: 3
# 02-26 23:57:12 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                        |      Macro-F1     |      Accuracy     |  Flip error-rate  |         MAE         |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_64D.model | 69.81474803328392 | 70.66356228172293 | 8.381839348079161 | 0.37718277066356226 |
# +------+---------+---------------------+---------------+--------------------+---------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_referral_sites_lvl_one_unweighted_128D.model
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_128D.model |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# 02-26 23:57:19 train        INFO     Start training...
# 02-26 23:57:19 train        INFO     Fold: 0
# 02-26 23:57:24 train        INFO     Fold: 1
# 02-26 23:57:31 train        INFO     Fold: 2
# 02-26 23:57:35 train        INFO     Fold: 3
# 02-26 23:57:39 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+--------------------+-------------------+------------------+---------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |      Macro-F1      |      Accuracy     | Flip error-rate  |         MAE         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+--------------------+-------------------+------------------+---------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_128D.model | 54.069554448321725 | 63.09662398137369 | 9.31315483119907 | 0.46216530849825377 |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+--------------------+-------------------+------------------+---------------------+
#
#  --------------------------------------------------
#
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_128D.model |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# 02-26 23:57:44 train        INFO     Start training...
# 02-26 23:57:44 train        INFO     Fold: 0
# 02-26 23:57:50 train        INFO     Fold: 1
# 02-26 23:57:55 train        INFO     Fold: 2
# 02-26 23:57:59 train        INFO     Fold: 3
# 02-26 23:58:03 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |      Macro-F1     |      Accuracy     |  Flip error-rate  |        MAE         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_128D.model | 68.82413477512324 | 69.49941792782305 | 8.963911525029102 | 0.3946449359720605 |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_referral_sites_lvl_one_unweighted_256D.model
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_256D.model |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# 02-26 23:58:11 train        INFO     Start training...
# 02-26 23:58:11 train        INFO     Fold: 0
# 02-26 23:58:16 train        INFO     Fold: 1
# 02-26 23:58:21 train        INFO     Fold: 2
# 02-26 23:58:26 train        INFO     Fold: 3
# 02-26 23:58:31 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+--------------------+--------------------+------------------+--------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |      Macro-F1      |      Accuracy      | Flip error-rate  |        MAE         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+--------------------+--------------------+------------------+--------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_256D.model | 53.849599770123326 | 62.398137369033755 | 9.31315483119907 | 0.4691501746216531 |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+--------------------+--------------------+------------------+--------------------+
#
#  --------------------------------------------------
#
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_256D.model |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# 02-26 23:58:39 train        INFO     Start training...
# 02-26 23:58:39 train        INFO     Fold: 0
# 02-26 23:58:46 train        INFO     Fold: 1
# 02-26 23:58:53 train        INFO     Fold: 2
# 02-26 23:58:57 train        INFO     Fold: 3
# 02-26 23:59:01 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+------------------+-----------------+-------------------+---------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |     Macro-F1     |     Accuracy    |  Flip error-rate  |         MAE         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+------------------+-----------------+-------------------+---------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_256D.model | 69.3601885803015 | 69.965075669383 | 8.847497089639116 | 0.38882421420256114 |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+------------------+-----------------+-------------------+---------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_referral_sites_lvl_one_unweighted_512D.model
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_512D.model |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# 02-26 23:59:11 train        INFO     Start training...
# 02-26 23:59:11 train        INFO     Fold: 0
# 02-26 23:59:18 train        INFO     Fold: 1
# 02-26 23:59:26 train        INFO     Fold: 2
# 02-26 23:59:32 train        INFO     Fold: 3
# 02-26 23:59:41 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |      Macro-F1     |      Accuracy     |  Flip error-rate  |         MAE         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_512D.model | 54.29470249973304 | 62.16530849825378 | 8.731082654249127 | 0.46565774155995343 |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
#
#  --------------------------------------------------
#
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_512D.model |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+
# 02-26 23:59:52 train        INFO     Start training...
# 02-26 23:59:52 train        INFO     Fold: 0
# 02-27 00:00:04 train        INFO     Fold: 1
# 02-27 00:00:14 train        INFO     Fold: 2
# 02-27 00:00:22 train        INFO     Fold: 3
# 02-27 00:00:31 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+------------------+-------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                         features                         |      Macro-F1     |      Accuracy     | Flip error-rate  |        MAE        |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+------------------+-------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_512D.model | 69.54116410044651 | 70.31431897555296 | 9.31315483119907 | 0.389988358556461 |
# +------+---------+---------------------+---------------+--------------------+----------------------------------------------------------+-------------------+-------------------+------------------+-------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_referral_sites_lvl_one_unweighted_1024D.model
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                          features                         |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_1024D.model |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# 02-27 00:01:00 train        INFO     Start training...
# 02-27 00:01:00 train        INFO     Fold: 0
# 02-27 00:01:23 train        INFO     Fold: 1
# 02-27 00:01:44 train        INFO     Fold: 2
# 02-27 00:02:05 train        INFO     Fold: 3
# 02-27 00:02:25 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+--------------------+--------------------+-------------------+--------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                          features                         |      Macro-F1      |      Accuracy      |  Flip error-rate  |        MAE         |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+--------------------+--------------------+-------------------+--------------------+
# | fact | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_1024D.model | 55.258812474972565 | 63.445867287543656 | 8.963911525029102 | 0.4551804423748545 |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+--------------------+--------------------+-------------------+--------------------+
#
#  --------------------------------------------------
#
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                          features                         |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_1024D.model |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# 02-27 00:02:47 train        INFO     Start training...
# 02-27 00:02:47 train        INFO     Fold: 0
# 02-27 00:03:09 train        INFO     Fold: 1
# 02-27 00:03:31 train        INFO     Fold: 2
# 02-27 00:03:51 train        INFO     Fold: 3
# 02-27 00:04:12 train        INFO     Fold: 4
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | task | dataset | classification_mode | type_training | normalize_features |                          features                         |      Macro-F1     |      Accuracy     |  Flip error-rate  |        MAE         |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | bias | acl2020 |  single classifier  |    combine    |       False        | corpus_2020_referral_sites_lvl_one_unweighted_1024D.model | 70.39208021305208 | 71.24563445867288 | 9.545983701979045 | 0.3830034924330617 |
# +------+---------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
#
#  ==================================================
