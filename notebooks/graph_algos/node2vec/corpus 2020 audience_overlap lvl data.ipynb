# %%
import pandas as pd
import sys
import os
sys.path.insert(0, '../../../')

from notebooks.utils import (
    _ALEXA_DATA_PATH, load_level_data,
    create_overlap_nodes, export_model_as_feature, create_node2vec_model
)
from train import run_experiment
# Out:
# 2022-01-14 11:28:16.563492: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load audience overlap edges for level 1

# %%
level = 1
audience_overlap_sites = load_level_data(os.path.join(_ALEXA_DATA_PATH, 'corpus_2020_audience_overlap_sites_scrapping_result.json'), level=level)
audience_overlap_sites_NODES = create_overlap_nodes(audience_overlap_sites)

print(audience_overlap_sites_NODES[:5])
# Out:
# 01-14 11:28:18 notebooks.utils INFO     Loaded 3489 nodes with records level <= 1 and child size:16981
# [('crooked.com', 'votesaveamerica.com'), ('crooked.com', 'art19.com'), ('crooked.com', 'promocodeportal.com'), ('crooked.com', 'mediamatters.org'), ('crooked.com', 'actblue.com')]

# %%
edge_df = pd.DataFrame(audience_overlap_sites_NODES, columns=['source', 'target'])

edge_df.head()
# Out:
#         source               target
# 0  crooked.com  votesaveamerica.com
# 1  crooked.com            art19.com
# 2  crooked.com  promocodeportal.com
# 3  crooked.com     mediamatters.org
# 4  crooked.com          actblue.com

# %% [markdown]
# # Create Graph

# %%
import stellargraph as sg

G = sg.StellarGraph(edges=edge_df)

print(G.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 10161, Edges: 17010
#
#  Node types:
#   default: [10161]
#     Features: none
#     Edge types: default-default->default
#
#  Edge types:
#     default-default->default: [17010]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# # Create Node2Vec models

# %%
models = create_node2vec_model(G, dimensions=[64, 128, 256, 512, 1024], is_weighted=False,
                               prefix='corpus_2020_audience_overlap_lvl_one')
# Out:
# Start creating random walks
# Number of random walks: 101610
# 01-14 11:38:30 gensim.models.word2vec INFO     collecting all words and their counts
# 01-14 11:38:30 gensim.models.word2vec INFO     PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 01-14 11:38:30 gensim.models.word2vec INFO     PROGRESS: at sentence #10000, processed 1000000 words, keeping 10149 word types
# 01-14 11:38:30 gensim.models.word2vec INFO     PROGRESS: at sentence #20000, processed 2000000 words, keeping 10154 word types
# 64 corpus_2020_audience_overlap_lvl_one_unweighted_64D.model
# 01-14 11:38:30 gensim.models.word2vec INFO     PROGRESS: at sentence #30000, processed 3000000 words, keeping 10161 word types
# 01-14 11:38:30 gensim.models.word2vec INFO     PROGRESS: at sentence #40000, processed 4000000 words, keeping 10161 word types
# 01-14 11:38:30 gensim.models.word2vec INFO     PROGRESS: at sentence #50000, processed 5000000 words, keeping 10161 word types
# 01-14 11:38:31 gensim.models.word2vec INFO     PROGRESS: at sentence #60000, processed 6000000 words, keeping 10161 word types
# 01-14 11:38:31 gensim.models.word2vec INFO     PROGRESS: at sentence #70000, processed 7000000 words, keeping 10161 word types
# 01-14 11:38:31 gensim.models.word2vec INFO     PROGRESS: at sentence #80000, processed 8000000 words, keeping 10161 word types
# 01-14 11:38:31 gensim.models.word2vec INFO     PROGRESS: at sentence #90000, processed 9000000 words, keeping 10161 word types
# 01-14 11:38:31 gensim.models.word2vec INFO     PROGRESS: at sentence #100000, processed 10000000 words, keeping 10161 word types
# 01-14 11:38:31 gensim.models.word2vec INFO     collected 10161 word types from a corpus of 10161000 raw words and 101610 sentences
# 01-14 11:38:31 gensim.models.word2vec INFO     Creating a fresh vocabulary
# 01-14 11:38:31 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 10161 unique words (100.0%% of original 10161, drops 0)', 'datetime': '2022-01-14T11:38:31.495676', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:38:31 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 10161000 word corpus (100.0%% of original 10161000, drops 0)', 'datetime': '2022-01-14T11:38:31.496417', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:38:31 gensim.models.word2vec INFO     deleting the raw counts dictionary of 10161 items
# 01-14 11:38:31 gensim.models.word2vec INFO     sample=0.001 downsamples 0 most-common words
# 01-14 11:38:31 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 10161000 word corpus (100.0%% of prior 10161000)', 'datetime': '2022-01-14T11:38:31.555710', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:38:31 gensim.models.word2vec INFO     estimated required memory for 10161 words and 64 dimensions: 10282932 bytes
# 01-14 11:38:31 gensim.models.word2vec INFO     resetting layer weights
# 01-14 11:38:31 gensim.utils INFO     Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-01
gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 25.88% examples, 652551 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:40 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 32.38% examples, 653278 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:41 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 38.87% examples, 653620 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:42 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 45.47% examples, 655798 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:43 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 52.06% examples, 655301 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:44 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 58.56% examples, 655412 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:45 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 65.05% examples, 655853 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:46 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 71.74% examples, 656520 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:47 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 78.24% examples, 656373 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:48 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 84.64% examples, 655524 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:49 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 91.13% examples, 655236 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:50 gensim.models.word2vec INFO     EPOCH 5 - PROGRESS: at 97.63% examples, 655330 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:51 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 01-14 11:39:51 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 01-14 11:39:51 gensim.models.word2vec INFO     EPOCH - 5 : training on 10161000 raw words (10161000 effective words) took 15.6s, 652716 effective words/s
# 01-14 11:39:51 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training on 50805000 raw words (50805000 effective words) took 79.4s, 640085 effective words/s', 'datetime': '2022-01-14T11:39:51.040535', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 01-14 11:39:51 gensim.utils INFO     Word2Vec lifecycle event {'params': 'Word2Vec(vocab=10161, vector_size=64, alpha=0.025)', 'datetime': '2022-01-14T11:39:51.041110', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 01-14 11:39:51 gensim.utils INFO     Word2Vec lifecycle event {'fname_or_handle': '/Users/panayot/Documents/News-Media-Peers/models/corpus_2020_audience_overlap_lvl_one_unweighted_64D.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-01-14T11:39:51.042574', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# 01-14 11:39:51 gensim.utils INFO     not storing attribute cum_table
# 01-14 11:39:51 gensim.utils INFO     saved /Users/panayot/Documents/News-Media-Peers/models/corpus_2020_audience_overlap_lvl_one_unweighted_64D.model
# 01-14 11:39:51 gensim.models.word2vec INFO     collecting all words and their counts
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #10000, processed 1000000 words, keeping 10149 word types
# Successful save of model: corpus_2020_audience_overlap_lvl_one_unweighted_64D.model!
# 128 corpus_2020_audience_overlap_lvl_one_unweighted_128D.model
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #20000, processed 2000000 words, keeping 10154 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #30000, processed 3000000 words, keeping 10161 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #40000, processed 4000000 words, keeping 10161 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #50000, processed 5000000 words, keeping 10161 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #60000, processed 6000000 words, keeping 10161 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #70000, processed 7000000 words, keeping 10161 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #80000, processed 8000000 words, keeping 10161 word types
# 01-14 11:39:51 gensim.models.word2vec INFO     PROGRESS: at sentence #90000, processed 9000000 words, keeping 10161 word types
# 01-14 11:39:52 gensim.models.word2vec INFO     PROGRESS: at sentence #100000, processed 10000000 words, keeping 10161 word types
# 01-14 11:39:52 gensim.models.word2vec INFO     collected 10161 word types from a corpus of 10161000 raw words and 101610 sentences
# 01-14 11:39:52 gensim.models.word2vec INFO     Creating a fresh vocabulary
# 01-14 11:39:52 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 10161 unique words (100.0%% of original 10161, drops 0)', 'datetime': '2022-01-14T11:39:52.082313', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:39:52 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 10161000 word corpus (100.0%% of original 10161000, drops 0)', 'datetime': '2022-01-14T11:39:52.082971', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:39:52 gensim.models.word2vec INFO     deleting the raw counts dictionary of 10161 items
# 01-14 11:39:52 gensim.models.word2vec INFO     sample=0.001 downsamples 0 most-common words
# 01-14 11:39:52 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 10161000 word corpus (100.0%% of prior 10161000)', 'datetime': '2022-01-14T11:39:52.140611', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:39:52 gensim.models.word2vec INFO     estimated required memory for 10161 words and 128 dimensions: 15485364 bytes
# 01-14 11:39:52 gensim.models.word2vec INFO     resetting layer weights
# 01-14 11:39:52 gensim.utils INFO     Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-01-14T11:39:52.245988', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 01-14 11:39:52 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training model with 2 workers on 10161 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-01-14T11:39:52.246623', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 01-14 11:39:53 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 3.84% examples, 382849 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:54 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 7.97% examples, 395974 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:55 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 12.40% examples, 411493 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:56 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 17.12% examples, 427491 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:57 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 22.14% examples, 442119 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:58 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 27.06% examples, 450570 words/s, in_qsize 3, out_qsize 0
# 01-14 11:39:59 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 32.08% examples, 458586 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:00 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 37.20% examples, 465802 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:01 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 42.61% examples, 474354 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:02 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 47.93% examples, 480114 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:03 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 53.44% examples, 487267 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:04 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 58.85% examples, 492341 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:05 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 64.46% examples, 497412 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:06 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 69.97% examples, 501310 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:07 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 75.58% examples, 505456 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:08 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 81.00% examples, 508077 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:09 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 86.61% examples, 511346 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:10 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 91.43% examples, 509939 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40:11 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 95.56% examples, 504597 words/s, in_qsize 3, out_qsize 0
# 01-14 11:40
gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training on 50805000 raw words (50805000 effective words) took 91.0s, 558238 effective words/s', 'datetime': '2022-01-14T11:41:23.258705', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 01-14 11:41:23 gensim.utils INFO     Word2Vec lifecycle event {'params': 'Word2Vec(vocab=10161, vector_size=128, alpha=0.025)', 'datetime': '2022-01-14T11:41:23.259255', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 01-14 11:41:23 gensim.utils INFO     Word2Vec lifecycle event {'fname_or_handle': '/Users/panayot/Documents/News-Media-Peers/models/corpus_2020_audience_overlap_lvl_one_unweighted_128D.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-01-14T11:41:23.260778', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# 01-14 11:41:23 gensim.utils INFO     not storing attribute cum_table
# 01-14 11:41:23 gensim.utils INFO     saved /Users/panayot/Documents/News-Media-Peers/models/corpus_2020_audience_overlap_lvl_one_unweighted_128D.model
# 01-14 11:41:23 gensim.models.word2vec INFO     collecting all words and their counts
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #10000, processed 1000000 words, keeping 10149 word types
# Successful save of model: corpus_2020_audience_overlap_lvl_one_unweighted_128D.model!
# 256 corpus_2020_audience_overlap_lvl_one_unweighted_256D.model
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #20000, processed 2000000 words, keeping 10154 word types
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #30000, processed 3000000 words, keeping 10161 word types
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #40000, processed 4000000 words, keeping 10161 word types
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #50000, processed 5000000 words, keeping 10161 word types
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #60000, processed 6000000 words, keeping 10161 word types
# 01-14 11:41:23 gensim.models.word2vec INFO     PROGRESS: at sentence #70000, processed 7000000 words, keeping 10161 word types
# 01-14 11:41:24 gensim.models.word2vec INFO     PROGRESS: at sentence #80000, processed 8000000 words, keeping 10161 word types
# 01-14 11:41:24 gensim.models.word2vec INFO     PROGRESS: at sentence #90000, processed 9000000 words, keeping 10161 word types
# 01-14 11:41:24 gensim.models.word2vec INFO     PROGRESS: at sentence #100000, processed 10000000 words, keeping 10161 word types
# 01-14 11:41:24 gensim.models.word2vec INFO     collected 10161 word types from a corpus of 10161000 raw words and 101610 sentences
# 01-14 11:41:24 gensim.models.word2vec INFO     Creating a fresh vocabulary
# 01-14 11:41:24 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 10161 unique words (100.0%% of original 10161, drops 0)', 'datetime': '2022-01-14T11:41:24.292946', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:41:24 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 10161000 word corpus (100.0%% of original 10161000, drops 0)', 'datetime': '2022-01-14T11:41:24.293782', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:41:24 gensim.models.word2vec INFO     deleting the raw counts dictionary of 10161 items
# 01-14 11:41:24 gensim.models.word2vec INFO     sample=0.001 downsamples 0 most-common words
# 01-14 11:41:24 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 10161000 word corpus (100.0%% of prior 10161000)', 'datetime': '2022-01-14T11:41:24.351302', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 01-14 11:41:24 gensim.models.word2vec INFO     estimated required memory for 10161 words and 256 dimensions: 25890228 bytes
# 01-14 11:41:24 gensim.models.word2vec INFO     resetting layer weights
# 01-14 11:41:24 gensim.utils INFO     Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-01-14T11:41:24.470955', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 01-14 11:41:24 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training model with 2 workers on 10161 vocabulary and 256 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-01-14T11:41:24.471612', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 01-14 11:41:25 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 2.26% examples, 216804 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:26 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 4.63% examples, 225102 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:27 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 7.09% examples, 231823 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:28 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 9.74% examples, 239853 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:29 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 12.50% examples, 246824 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:30 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 15.25% examples, 252055 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:31 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 18.11% examples, 256535 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:32 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 21.06% examples, 261537 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:33 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 24.01% examples, 265093 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:34 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 26.97% examples, 267743 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:35 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 29.92% examples, 270054 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:36 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 32.87% examples, 272177 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:37 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 35.92% examples, 274951 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:38 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 39.07% examples, 277710 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:39 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 42.22% examples, 280099 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:40 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 45.37% examples, 282287 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:41 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 48.52% examples, 284094 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:42 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 51.57% examples, 284909 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:43 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at 54.72% examples, 286404 words/s, in_qsize 3, out_qsize 0
# 01-14 11:41:44 gensim.models.word2vec INFO     EPOCH 1 - PROGRESS: at
gensim.models.word2vec INFO     worker thread finished; awaiting finish of 1 more threads
# 01-14 11:55:15 gensim.models.word2vec INFO     worker thread finished; awaiting finish of 0 more threads
# 01-14 11:55:15 gensim.models.word2vec INFO     EPOCH - 5 : training on 10161000 raw words (10161000 effective words) took 79.9s, 127174 effective words/s
# 01-14 11:55:15 gensim.utils INFO     Word2Vec lifecycle event {'msg': 'training on 50805000 raw words (50805000 effective words) took 404.0s, 125758 effective words/s', 'datetime': '2022-01-14T11:55:15.288396', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 01-14 11:55:15 gensim.utils INFO     Word2Vec lifecycle event {'params': 'Word2Vec(vocab=10161, vector_size=1024, alpha=0.025)', 'datetime': '2022-01-14T11:55:15.288858', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 01-14 11:55:15 gensim.utils INFO     Word2Vec lifecycle event {'fname_or_handle': '/Users/panayot/Documents/News-Media-Peers/models/corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2022-01-14T11:55:15.289925', 'gensim': '4.1.2', 'python': '3.8.12 (default, Oct 12 2021, 06:23:56) \n[Clang 10.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'saving'}
# 01-14 11:55:15 gensim.utils INFO     not storing attribute cum_table
# 01-14 11:55:15 gensim.utils INFO     saved /Users/panayot/Documents/News-Media-Peers/models/corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model
# Successful save of model: corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model!

# %% [markdown]
# # Export embeddings as feature

# %%
for model_name, model in models.items():
    print(f'Processing model: {model_name}')
    embeddings_wv = {site: model.wv.get_vector(site).tolist() for site in G.nodes()}
    export_model_as_feature(embeddings_wv, model_name, data_year='2020')
    run_experiment(features=model_name, dataset='acl2020', task='fact')
    print('\n', '-'*50, '\n')
    run_experiment(features=model_name, dataset='acl2020', task='bias')
    print('\n', '='*50, '\n')
# Out:
# Processing model: corpus_2020_audience_overlap_lvl_one_unweighted_64D.model
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                         |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_64D.model |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# 01-14 11:55:16 train        INFO     Start training...
# 01-14 11:55:16 train        INFO     Fold: 0
# 01-14 11:55:21 train        INFO     Fold: 1
# 01-14 11:55:23 train        INFO     Fold: 2
# 01-14 11:55:25 train        INFO     Fold: 3
# 01-14 11:55:27 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | task | classification_mode | type_training | normalize_features |                          features                         |      Macro-F1     |      Accuracy     |  Flip error-rate  |         MAE         |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_64D.model | 54.94154975237065 | 64.26076833527358 | 8.149010477299184 | 0.43888242142025613 |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
#
#  --------------------------------------------------
#
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                         |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_64D.model |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+
# 01-14 11:55:29 train        INFO     Start training...
# 01-14 11:55:29 train        INFO     Fold: 0
# 01-14 11:55:33 train        INFO     Fold: 1
# 01-14 11:55:35 train        INFO     Fold: 2
# 01-14 11:55:38 train        INFO     Fold: 3
# 01-14 11:55:40 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-----------------+-------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                          features                         |      Macro-F1     |     Accuracy    |  Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-----------------+-------------------+--------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_64D.model | 69.05883036510843 | 70.081490104773 | 7.683352735739232 | 0.3760186263096624 |
# +------+---------------------+---------------+--------------------+-----------------------------------------------------------+-------------------+-----------------+-------------------+--------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_audience_overlap_lvl_one_unweighted_128D.model
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_128D.model |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# 01-14 11:55:45 train        INFO     Start training...
# 01-14 11:55:45 train        INFO     Fold: 0
# 01-14 11:55:48 train        INFO     Fold: 1
# 01-14 11:55:51 train        INFO     Fold: 2
# 01-14 11:55:53 train        INFO     Fold: 3
# 01-14 11:55:55 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |      Macro-F1     |      Accuracy     |  Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_128D.model | 55.90694998794245 | 64.14435389988358 | 8.614668218859139 | 0.4447031431897555 |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
#
#  --------------------------------------------------
#
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_128D.model |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# 01-14 11:55:58 train        INFO     Start training...
# 01-14 11:55:58 train        INFO     Fold: 0
# 01-14 11:56:02 train        INFO     Fold: 1
# 01-14 11:56:05 train        INFO     Fold: 2
# 01-14 11:56:08 train        INFO     Fold: 3
# 01-14 11:56:10 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |      Macro-F1     |      Accuracy     | Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_128D.model | 68.57006360857841 | 69.49941792782305 | 9.31315483119907 | 0.3981373690337602 |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_audience_overlap_lvl_one_unweighted_256D.model
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_256D.model |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# 01-14 11:56:19 train        INFO     Start training...
# 01-14 11:56:19 train        INFO     Fold: 0
# 01-14 11:56:25 train        INFO     Fold: 1
# 01-14 11:56:30 train        INFO     Fold: 2
# 01-14 11:56:34 train        INFO     Fold: 3
# 01-14 11:56:39 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |      Macro-F1     |      Accuracy     | Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_256D.model | 55.41786090787247 | 64.49359720605355 | 9.19674039580908 | 0.4470314318975553 |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+------------------+--------------------+
#
#  --------------------------------------------------
#
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_256D.model |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# 01-14 11:56:46 train        INFO     Start training...
# 01-14 11:56:46 train        INFO     Fold: 0
# 01-14 11:56:53 train        INFO     Fold: 1
# 01-14 11:56:58 train        INFO     Fold: 2
# 01-14 11:57:03 train        INFO     Fold: 3
# 01-14 11:57:08 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |      Macro-F1     |      Accuracy     |  Flip error-rate  |         MAE         |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_256D.model | 70.47128237259815 | 71.36204889406287 | 8.614668218859139 | 0.37252619324796277 |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+---------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_audience_overlap_lvl_one_unweighted_512D.model
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_512D.model |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# 01-14 11:57:24 train        INFO     Start training...
# 01-14 11:57:24 train        INFO     Fold: 0
# 01-14 11:57:33 train        INFO     Fold: 1
# 01-14 11:57:40 train        INFO     Fold: 2
# 01-14 11:57:47 train        INFO     Fold: 3
# 01-14 11:57:54 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |      Macro-F1     |      Accuracy     |  Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_512D.model | 53.60886198138948 | 62.74738067520372 | 8.498253783469151 | 0.4575087310826543 |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
#
#  --------------------------------------------------
#
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_512D.model |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+
# 01-14 11:58:03 train        INFO     Start training...
# 01-14 11:58:03 train        INFO     Fold: 0
# 01-14 11:58:12 train        INFO     Fold: 1
# 01-14 11:58:18 train        INFO     Fold: 2
# 01-14 11:58:25 train        INFO     Fold: 3
# 01-14 11:58:31 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+------------------+-------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                          features                          |      Macro-F1     |     Accuracy     |  Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+------------------+-------------------+--------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_512D.model | 71.14307602895335 | 71.9441210710128 | 7.566938300349244 | 0.3562281722933644 |
# +------+---------------------+---------------+--------------------+------------------------------------------------------------+-------------------+------------------+-------------------+--------------------+
#
#  ==================================================
#
# Processing model: corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                           features                          |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+
# 01-14 11:58:54 train        INFO     Start training...
# 01-14 11:58:54 train        INFO     Fold: 0
# 01-14 11:59:14 train        INFO     Fold: 1
# 01-14 11:59:32 train        INFO     Fold: 2
# 01-14 11:59:53 train        INFO     Fold: 3
# 01-14 12:00:12 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+-------------------+-------------------+-------------------+-------------------+
# | task | classification_mode | type_training | normalize_features |                           features                          |      Macro-F1     |      Accuracy     |  Flip error-rate  |        MAE        |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+-------------------+-------------------+-------------------+-------------------+
# | fact |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model | 57.67208611044041 | 65.65774155995344 | 7.683352735739232 | 0.420256111757858 |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+-------------------+-------------------+-------------------+-------------------+
#
#  --------------------------------------------------
#
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+
# | task | classification_mode | type_training | normalize_features |                           features                          |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+
# 01-14 12:00:33 train        INFO     Start training...
# 01-14 12:00:33 train        INFO     Fold: 0
# 01-14 12:00:53 train        INFO     Fold: 1
# 01-14 12:01:11 train        INFO     Fold: 2
# 01-14 12:01:29 train        INFO     Fold: 3
# 01-14 12:01:50 train        INFO     Fold: 4
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | task | classification_mode | type_training | normalize_features |                           features                          |      Macro-F1     |      Accuracy     |  Flip error-rate  |        MAE         |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
# | bias |  single classifier  |    combine    |       False        | corpus_2020_audience_overlap_lvl_one_unweighted_1024D.model | 72.36545847488097 | 73.22467986030267 | 7.916181606519208 | 0.3469150174621653 |
# +------+---------------------+---------------+--------------------+-------------------------------------------------------------+-------------------+-------------------+-------------------+--------------------+
#
#  ==================================================
